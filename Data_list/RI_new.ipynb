# %%
import datetime as dt


def RT2RI(date_pre , RT ) :
    Exday = dt.datetime
    pre = date_pre.split("-")
    year = int(pre[0])
    mon = int(pre[1])
    day = int(pre[2])
    # print year , mon , day
    date = Exday(year , mon , day)
        
    if date >= Exday(2015,12,12) :
        if RT >= 35.460 :
            return 0
        elif RT >= 32.397 :
            i = [14.000,32.397,35.460]
            return (i[0]+(RT - i[1])/(i[2] - RT) )           
        elif RT >= 29.153 :
            i = [13.000,29.153,32.397] 
            return (i[0]+(RT - i[1])/(i[2] - RT) )
        elif RT >= 25.751 :
            i = [12.000,25.751,29.153] 
            return (i[0]+(RT - i[1])/(i[2] - RT) )
        elif RT >= 22.199 :
            i = [11.000,22.199,25.751] 
            return (i[0]+(RT - i[1])/(i[2] - RT) )            
        elif RT >= 18.571 :
            i = [10.000,18.571,22.199] 
            return (i[0]+(RT - i[1])/(i[2] - RT) )
        elif RT >= 15.090 :
            i = [9.000,15.090,18.571] 
            return (i[0]+(RT - i[1])/(i[2] - RT) )
        elif RT >= 12.136 :
            i = [8.000,12.136,15.090] 
            return (i[0]+(RT - i[1])/(i[2] - RT) )     
        else :
            i = [7.000,10.028,12.136]
            return (i[0]+(RT - i[1])/(i[2] - RT) )     
        
    elif date >= Exday(2015,11,21):
        if RT >= 34.270 :
            return 0
        elif RT >= 28.491 :
            i = [14.000,28.491,34.270] 
            return (i[0]+(RT - i[1])/(i[2] - RT) )           
        elif RT >= 25.348 :
            i = [13.000,25.348,28.491] 
            return (i[0]+(RT - i[1])/(i[2] - RT) )
        elif RT >= 22.091 :
            i = [12.000,22.091,25.348] 
            return (i[0]+(RT - i[1])/(i[2] - RT) )
        elif RT >= 18.741 :
            i = [11.000,18.741,22.091] 
            return (i[0]+(RT - i[1])/(i[2] - RT) )            
        elif RT >= 15.449 :
            i = [10.000,15.449,18.741] 
            return (i[0]+(RT - i[1])/(i[2] - RT) )
        elif RT >= 12.543 :
            i = [9.000,12.543,15.449] 
            return (i[0]+(RT - i[1])/(i[2] - RT) )
        elif RT >= 10.354 :
            i = [8.000,10.354,12.543] 
            return (i[0]+(RT - i[1])/(i[2] - RT) )     
        else :
            i = [7.000,8.983,10.354] 
            return (i[0]+(RT - i[1])/(i[2] - RT) )     
    
    
    elif date > Exday(2015,11,10) :
        if RT >= 34.326 :
            return 0
        elif RT >= 31.231 :
            i = [14.000,31.231,34.326] 
            return (i[0]+(RT - i[1])/(i[2] - RT) )           
        elif RT >= 27.975 :
            i = [13.000,27.975,31.231] 
            return (i[0]+(RT - i[1])/(i[2] - RT) )
        elif RT >= 24.559 :
            i = [12.000,24.559,27.975] 
            return (i[0]+(RT - i[1])/(i[2] - RT) )
        elif RT >= 20.997 :
            i = [11.000,20.997,24.559] 
            return (i[0]+(RT - i[1])/(i[2] - RT) )            
        elif RT >= 17.390 :
            i = [10.000,17.390,20.997] 
            return (i[0]+(RT - i[1])/(i[2] - RT) )
        elif RT >= 13.997 :
            i = [9.000,13.997,17.390] 
            return (i[0]+(RT - i[1])/(i[2] - RT) )
        elif RT >= 11.215 :
            i = [8.000,11.215,13.997] 
            return (i[0]+(RT - i[1])/(i[2] - RT) )     
        else :
            i = [7.000,9.308,11.215]
            return (i[0]+(RT - i[1])/(i[2] - RT) )     
        
    else :
        # 2015.11.05 column
        if RT >= 34.462 :
            return 0
        elif RT >= 31.362 :
            i = [14.000,31.362,34.462]
            return (i[0]+(RT - i[1])/(i[2] - RT) )           
        elif RT >= 28.109 :
            i = [13.000,28.109,31.362]
            return (i[0]+(RT - i[1])/(i[2] - RT) )
        elif RT >= 24.690 :
            i = [12.000,24.690,28.109]
            return (i[0]+(RT - i[1])/(i[2] - RT) )
        elif RT >= 21.125 :
            i = [11.000,21.125,24.690]
            return (i[0]+(RT - i[1])/(i[2] - RT) )            
        elif RT >= 17.507 :
            i = [10.000,17.507,21.125]
            return (i[0]+(RT - i[1])/(i[2] - RT) )
        elif RT >= 14.100 :
            i = [9.000,14.100 ,17.507]
            return (i[0]+(RT - i[1])/(i[2] - RT) )
        elif RT >= 11.296 :
            i = [8.000,11.296,14.100]
            return (i[0]+(RT - i[1])/(i[2] - RT) )     
        else :
            i = [7.000,9.380 ,11.296]
            return (i[0]+(RT - i[1])/(i[2] - RT) )

# %%
import pandas as pd

CAS_re_lt = []

CAS = pd.DataFrame.from_csv("ful_CAS.csv")
for i in CAS.values.tolist() :
    i[4] # RT
    i[10] # Peak_ID
    m = i[10].split("-")
    sample_ID = m[0] + "-" + m[1]
    Time = "2015" + "-" + m[1][:2] + "-" + m[1][2:]
    RI =  RT2RI(Time , i[4]  ) 
    i = i + [RI , sample_ID]
    CAS_re_lt.append(i)

# %%
CAS_re = pd.DataFrame(CAS_re_lt)
CAS_re.head()
CAS_re = CAS_re.rename(columns={0: 'Class', 1: 'Sample',2:"Date",3: "Peak",4:"RT", 5: "scan_number",6 :"Intensity",\
                        7 : "Area%", 8 : "CAS_ID", 9 : "Quality",10 : "Peak_ID", 11 : "RI" , 12 : "Sample_ID"})

# %%
Retro = CAS_re
del Retro["RT"]
Retro.to_csv("CAS_renext.csv")
Retro.head()
# Out:
#   Class Sample        Date  Peak  scan_number  Intensity  Area%       CAS_ID  \
# 0    CU    CU3  2015/11/03     1          450     104584   0.14  000124-38-9
# 1    CU    CU3  2015/11/03     2          493     103807   0.14  000124-38-9
# 2    CU    CU3  2015/11/03     3         1981     103443   0.14  000563-46-2
# 3    CU    CU3  2015/11/03     3         1981     103443   0.14  000930-18-7
# 4    CU    CU3  2015/11/03     3         1981     103443   0.14  000627-20-3
#
#    Quality     Peak_ID        RI Sample_ID
# 0      4.0  CU3-1103-1  6.201155  CU3-1103
# 1      4.0  CU3-1103-2  6.204613  CU3-1103
# 2     35.0  CU3-1103-3  6.506075  CU3-1103
# 3     35.0  CU3-1103-3  6.506075  CU3-1103
# 4     35.0  CU3-1103-3  6.506075  CU3-1103

# %%
x = []
CAS_group = CAS_re.groupby("CAS_ID").groups

print "CAS-Group type : ",type(CAS_group)


for cas in CAS_group :
    x.append([cas,CAS_group[cas]])
"~~~~~~~~~~~~~~~~~~show dataframe ~~~~~~~~~~~~~~~~~~~~~~~~~~~~"
test_group_df = pd.DataFrame(x)
test_group_df = test_group_df.rename(columns={0: 'CAS_ID', 1: 'Sample_index'})
# test_group_df
test_group_df.head()
# Out:
# CAS-Group type :  <type 'dict'>
#         CAS_ID                                       Sample_index
# 0  013906-90-6                                             [4109]
# 1  043145-54-6                                             [9464]
# 2  000100-52-7  [231, 352, 476, 955, 1147, 1319, 1481, 1660, 1...
# 3  000194-59-2                        [1520, 11504, 18280, 23571]
# 4  010422-35-2                                             [1965]

# %%
CAS_re.ix[CAS_group["000100-52-7"]]
# Out:
#       Class Sample        Date  Peak      RT  scan_number  Intensity  Area%  \
# 231      CU    CU3  2015/11/25    34  14.643         3884      14356   0.05
# 352      CU    CU3  2015/12/17    42  17.196         4565      69104   0.10
# 476      CU    CU3  2015/11/07    35  16.053         4260      29045   0.09
# 955      CU    CU4  2015/11/18    42  14.677         3893      56934   0.08
# 1147     CU    CU4  2015/12/17    45  17.204         4567      18095   0.04
# 1319     CU    CU4  2015/11/03    44  16.199         4299     161343   0.21
# 1481     CU    CU4  2015/11/07    41  16.053         4260      57281   0.14
# 1660     CU    CU2  2015/11/14    37  14.820         3931      12307   0.16
# 1871     CU    CU2  2015/11/03    44  16.188         4296     113319   0.36
# 2061     CU    CU2  2015/12/17    39  17.200         4566      33033   0.35
# 2242     CU    CU2  2015/11/07    40  16.061         4262      48927   0.40
# ...

# %%
import numpy as np
from sklearn.cluster import MeanShift, estimate_bandwidth


def MeanScan(CAS_ID, cas_index_list , scan_list , bandwidth ) :
    # Y has index number of data frame
    Y = np.array(zip(cas_index_list,np.zeros(len(cas_index_list))), dtype=np.int)    
    X = np.array(zip(scan_list,np.zeros(len(scan_list))), dtype=np.int)
    ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
    ms.fit(X)
    # label of item
    labels = ms.labels_
    cluster_centers = ms.cluster_centers_
    labels_unique = np.unique(labels)
    n_clusters_ = len(labels_unique)
    # Let be check
    result = []
    for k in range(n_clusters_):
        my_members = labels == k
        result.append( [CAS_ID , k , list(Y[my_members, 0]) , list(X[my_members, 0])] )
        # CAS-ID  / sub cluster / dataframe index / real scan value
    return result
